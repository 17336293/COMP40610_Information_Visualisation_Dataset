# %%
#import packages
import numpy as np
import pandas as pd

# %% [markdown]
# # Clean the Origional Data

# %%
#read the data
df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-01-11/colony.csv")

# %%
#Remove values for the United States as a whole, as it causes double counting when ploting the line chart
df = df[df["state"]!="United States"]

# %%
#Treat missing values for Colony renovated
#df[df["colony_reno"].isna()==True]
df["colony_added"].fillna(0, inplace=True)
df["colony_reno"].fillna(0, inplace=True)
df["colony_lost"].fillna(0, inplace=True)
df["gross_gain"] = df["colony_added"]+df["colony_reno"]
df["net_gain"] = df["gross_gain"]-df["colony_lost"]

# %%
df.to_csv("colonyv2.csv")

# %% [markdown]
# # Clean the Data for a Choropleth Map

# %%
#get a list of states used in the dataset
states = df["state"].unique()

# %%
#create additional features
df["net_gain"] = (df["colony_reno"]+df["colony_added"])-df["colony_lost"]

# %%
#group by operation to summeries bee columns
dfBees = df.groupby(["state"]).mean()
dfBees.drop(columns=["year"], inplace=True)

# %%
dfBees = dfBees.round(2)

# %%
# Join with Longitude and Latitude loactions
dfMap = pd.read_json("https://gist.githubusercontent.com/meiqimichelle/7727723/raw/0109432d22f28fd1a669a3fd113e41c4193dbb5d/USstates_avg_latLong")
dfMap = dfMap .set_index('state')

# %%
#get a list of the states missing from the origional Bees file
dfMissingStates = dfMap[dfMap.index.isin(dfBees.index)==False]
dfMissingStates
# Out:
#                latitude  longitude
# state
# Alaska          61.3850  -152.2683
# Delaware        39.3498   -75.5148
# New Hampshire   43.4108   -71.5653
# Nevada          38.4199  -117.1219
# Rhode Island    41.6772   -71.5101

# %%
#Combine the two datasets together
dfConcat = pd.concat([dfBees,dfMap], axis=1, join="inner")

# %%
#Add the missing states to the dataset
dfConcat = dfConcat.append(dfMissingStates)

# %%
#Adjust for missing values
dfConcatNA = dfConcat.fillna("NA")

# %%
dfConcatNA
# Out:
#                 colony_n colony_max colony_lost colony_lost_pct colony_added  \
# state
# Alabama           7900.0     8560.0     1258.08           15.28      1079.62
# Arizona          28260.0    29380.0     5088.46           17.68      5176.54
# Arkansas         21580.0    22440.0     3242.31           14.56      3063.85
# California      940400.0  1193200.0   132923.08           11.16    127346.15
# Colorado         19580.0    25300.0     3618.46           13.96      2573.08
# Connecticut       3516.0     3576.0      248.08             7.2       350.77
# Florida         244480.0   265200.0    33730.77           13.44     43846.15
# Georgia         122680.0   129200.0    16423.08           13.24     20315.38
# Hawaii           15480.0    15480.0      801.15            5.46      1043.08
# Idaho            96680.0   124840.0    12230.77           10.24     10646.15
# Illinois         11240.0    11660.0      1575.0           14.48      1636.15
# Indiana          10092.0    10880.0     1270.38           12.88      1436.92
# Iowa             28120.0    32440.0     3203.85           11.12       4785.0
# Kansas            5824.0     6296.0     1165.77           19.32       1035.0
# Kentucky          7800.0     8356.0     1146.92           14.72      1010.38
# Louisiana        49800.0    52720.0     3871.92            7.52       4295.0
# Maine             5360.0    11100.0      843.46            8.52       374.62
# Maryland          7400.0     8360.0      965.77           12.08      1023.46
# Massachusetts     5784.0     7516.0      703.08            12.2       510.38
# Michigan         66760.0    80160.0     8680.77           11.56      6978.85
# Minnesota        75840.0    99400.0    10692.31           10.44      7892.69
# Mississippi      33460.0    42540.0     3746.15           10.16      6208.08
# Missouri          9272.0     9492.0      881.15           10.32       778.08
# Montana          77140.0   113080.0     7146.54            6.48      6392.69
# Nebraska         29740.0    40480.0     3506.15            8.72      2753.08
# New Jersey       11304.0    14240.0      663.46            5.28       666.15
# New Mexico        5744.0     6288.0     1107.31           16.92      1148.85
# Tennessee           751.54            7.62    2021.92     575.77   35.7449
# Texas             34351.15           12.48   79751.15   56789.62   31.1060
# Utah               2118.46            13.0    5801.54    2900.77   40.1135
# Vermont             103.08            2.77     500.77     168.08   44.0407
# Virginia            466.92            6.54    1612.31     636.54   37.7680
# Washington         6067.69             7.5   14056.92    5668.46   47.3917
# West Virginia       659.23            9.21    1428.85     556.92   38.4680
# Wisconsin          3348.85            7.55    7612.69    1612.69   44.2563
# Wyoming            1641.15            9.18    3571.54    1169.62   42.7475
# Alaska                  NA              NA         NA         NA   61.3850
# Delaware                NA              NA         NA         NA   39.3498
# New Hampshire           NA              NA         NA         NA   43.4108
# Nevada                  NA              NA         NA         NA   38.4199
# Rhode Island            NA              NA         NA         NA   41.6772
#
#                 longitude
# state
# Alabama          -86.8073
# Arizona         -111.3877
# Arkansas         -92.3809
# California      -119.7462
# Colorado        -105.3272
# Connecticut      -72.7622
# Florida          -81.7170
# Georgia          -83.6487
# Hawaii          -157.5311
# Idaho           -114.5103
# Illinois         -89.0022
# Indiana          -86.2604
# Iowa             -93.2140
# Kansas           -96.8005
# Kentucky         -84.6514
# Louisiana        -91.8749
# Maine            -69.3977
# Maryland         -76.7902
# Massachusetts    -71.5314
# Michigan         -84.5603
# Minnesota        -93.9196
# Mississippi      -89.6812
# Missouri         -92.3020
# Montana         -110.3261
# Nebraska         -98.2883
# New Jersey       -74.5089
# New Mexico      -106.2371
# New York         -74.9384
# North Carolina   -79.8431
# North Dakota     -99.7930
# Ohio             -82.7755
# Oklahoma         -96.9247
# Oregon          -122.1269
# Pennsylvania     -77.2640
# South Carolina   -80.9066
# South Dakota     -99.4632
# Tennessee        -86.7489
# Texas            -97.6475
# Utah            -111.8535
# Vermont          -72.7093
# Virginia         -78.2057
# Washington      -121.5708
# West Virginia    -80.9696
# Wisconsin        -89.6385
# Wyoming         -107.2085
# Alaska          -152.2683
# Delaware         -75.5148
# New Hampshire    -71.5653
# Nevada          -117.1219
# Rhode Island     -71.5101

# %%
#Add ID field 
idCsv = "https://raw.githubusercontent.com/vega/vega/master/docs/data/population_engineers_hurricanes.csv"
idDf = pd.read_csv(idCsv)
idDf=idDf[["id","state"]]
dfFinal = pd.merge(left=idDf, right=dfConcatNA, left_on='state', right_on='state')

# %%
dfFinal.dtypes
# Out:
# id                   int64
# state               object
# colony_n            object
# colony_max          object
# colony_lost         object
# colony_lost_pct     object
# colony_added        object
# colony_reno         object
# colony_reno_pct     object
# gross_gain          object
# net_gain            object
# latitude           float64
# longitude          float64
# dtype: object

# %%
#see states that are not includeded in the colonies dataset
dfFinal[dfFinal["colony_max"]=="NA"]
# Out:
#     id          state colony_n colony_max colony_lost colony_lost_pct  \
# 1    2         Alaska       NA         NA          NA              NA
# 7   10       Delaware       NA         NA          NA              NA
# 27  32         Nevada       NA         NA          NA              NA
# 28  33  New Hampshire       NA         NA          NA              NA
# 38  44   Rhode Island       NA         NA          NA              NA
#
#    colony_added colony_reno colony_reno_pct gross_gain net_gain  latitude  \
# 1            NA          NA              NA         NA       NA   61.3850
# 7            NA          NA              NA         NA       NA   39.3498
# 27           NA          NA              NA         NA       NA   38.4199
# 28           NA          NA              NA         NA       NA   43.4108
# 38           NA          NA              NA         NA       NA   41.6772
#
#     longitude
# 1   -152.2683
# 7    -75.5148
# 27  -117.1219
# 28   -71.5653
# 38   -71.5101

# %%
#remove these states and Save to CSV
dfFinal = dfFinal[dfFinal["colony_max"]!="NA"]
dfFinal.to_csv("beesv3.csv")
